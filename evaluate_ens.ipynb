# %%
import os
import sys
import time
import socket
import random
import argparse
import importlib
import scipy.misc
import statistics 
import numpy as np
import tensorflow as tf
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# Append python path
BASE_DIR = os.path.dirname(os.path.abspath('__file__'))
sys.path.append(BASE_DIR)
sys.path.append(os.path.join(BASE_DIR, 'utils'))
sys.path.append(os.path.join(BASE_DIR, 'models'))

# Import pointnet stuff
import pc_util
import provider
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # BASIC CONFIGURATION

# %%
BATCH_SIZE = 4
NUM_POINT = 1024
MODEL_DIR = 'log'
GPU_INDEX = 0
MODEL = importlib.import_module('dgcnn') # import network module
DUMP_DIR = 'dump'
VISUALIZATION = False
if not os.path.exists(DUMP_DIR):
    os.mkdir(DUMP_DIR)
    

HOSTNAME = socket.gethostname()
NUM_CLASSES = 40
SHAPE_NAMES = [line.rstrip() for line in \
    open(os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/shape_names.txt'))] 

# ModelNet40 official train/test split
TRAIN_FILES = provider.getDataFiles( \
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/train_files.txt'))
TEST_FILES = provider.getDataFiles(\
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/test_files.txt'))

# %% [markdown]
# # EVALUATE ONE EPOCH METHOD
#
# Args:
#
#   **sess** - tf session
#
#   **ops** - parameters
#
#
#
# Returns:
#
#   **loss** - mean classification loss
#
#   **accuracy** - instance classification accuracy
#
#   **class_accuracy** - class classification accuracy
#
#   **predictions** - array of the output ofthe classification module with shape: (N, 40), where N is the test clouds len
#
#   **true_labels** - true labels of test clouds with the lenght of N

# %%
def eval_one_epoch(sess, ops, num_votes=1, topk=1, verbose=False):
    error_cnt = 0
    is_training = False
    total_correct = 0
    total_seen = 0
    loss_sum = 0
    total_seen_class = [0 for _ in range(NUM_CLASSES)]
    total_correct_class = [0 for _ in range(NUM_CLASSES)]
    fout = open(os.path.join(DUMP_DIR, 'pred_label.txt'), 'w')
    pred_vals = []
    true_vals = []
    for fn in range(len(TEST_FILES)):
        if verbose:
            print('----'+str(fn)+'----')
        current_data, current_label = provider.loadDataFile(TEST_FILES[fn])
        current_data = current_data[:,0:NUM_POINT,:]
        current_label = np.squeeze(current_label)
        if verbose:
            print(current_data.shape)
        
        file_size = current_data.shape[0]
        num_batches = file_size // BATCH_SIZE
        if verbose:
            print(file_size)
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * BATCH_SIZE
            end_idx = (batch_idx+1) * BATCH_SIZE
            cur_batch_size = end_idx - start_idx
            
            # Aggregating BEG
            batch_loss_sum = 0 # sum of losses for the batch
            batch_pred_sum = np.zeros((cur_batch_size, NUM_CLASSES)) # score for classes
            batch_pred_classes = np.zeros((cur_batch_size, NUM_CLASSES)) # 0/1 for classes
            for vote_idx in range(num_votes):
                rotated_data = provider.rotate_point_cloud_by_angle(current_data[start_idx:end_idx, :, :],
                                                  vote_idx/float(num_votes) * np.pi * 2)
                feed_dict = {ops['pointclouds_pl']: rotated_data,
                             ops['labels_pl']: current_label[start_idx:end_idx],
                             ops['is_training_pl']: is_training}
                loss_val, pred_val = sess.run([ops['loss'], ops['pred']],
                                          feed_dict=feed_dict)
                batch_pred_sum += pred_val
                batch_pred_val = np.argmax(pred_val, 1)
                for el_idx in range(cur_batch_size):
                    batch_pred_classes[el_idx, batch_pred_val[el_idx]] += 1
                batch_loss_sum += (loss_val * cur_batch_size / float(num_votes))
                
            # DANIEL
            pred_vals.append(batch_pred_sum.copy())
            true_vals.append(current_label[start_idx:end_idx].copy())
        
            # pred_val_topk = np.argsort(batch_pred_sum, axis=-1)[:,-1*np.array(range(topk))-1]
            # pred_val = np.argmax(batch_pred_classes, 1)
            pred_val = np.argmax(batch_pred_sum, 1)
            # Aggregating END
            
            correct = np.sum(pred_val == current_label[start_idx:end_idx])
            # correct = np.sum(pred_val_topk[:,0:topk] == label_val)
            total_correct += correct
            total_seen += cur_batch_size
            loss_sum += batch_loss_sum

            for i in range(start_idx, end_idx):
                l = current_label[i]
                total_seen_class[l] += 1
                total_correct_class[l] += (pred_val[i-start_idx] == l)
                fout.write('%d, %d\n' % (pred_val[i-start_idx], l))
                
                if pred_val[i-start_idx] != l and VISUALIZATION: # ERROR CASE, DUMP!
                    img_filename = '%d_label_%s_pred_%s.jpg' % (error_cnt, SHAPE_NAMES[l],
                                                           SHAPE_NAMES[pred_val[i-start_idx]])
                    img_filename = os.path.join(DUMP_DIR, img_filename)
                    output_img = pc_util.point_cloud_three_views(np.squeeze(current_data[i, :, :]))
                    scipy.misc.imsave(img_filename, output_img)
                    error_cnt += 1
    
    eval_mean_loss = (loss_sum / float(total_seen))
    eval_instance_acc = (total_correct / float(total_seen))
    eval_class_acc = (np.mean(np.array(total_correct_class)/np.array(total_seen_class,dtype=np.float)))
    
    pred_vals = np.concatenate(pred_vals)
    true_vals = np.concatenate(true_vals)
    
    if verbose:
        print('eval mean loss: %f' % eval_mean_loss)
        print('eval accuracy: %f' % eval_instance_acc)
        print('eval avg class acc: %f' % eval_class_acc)
    
    class_accuracies = np.array(total_correct_class)/np.array(total_seen_class,dtype=np.float)
    if verbose:
        for i, name in enumerate(SHAPE_NAMES):
            print('%10s:\t%0.3f' % (name, class_accuracies[i]))
            
    return eval_mean_loss, eval_instance_acc, eval_class_acc, pred_vals, true_vals

# %% [markdown]
# # EVALUATE METHOD
#
# Args:
#
#   **model_num** - number of the pointnet model (i.e.: 3 to evaluate model_3.ckpt model)
#
#   **num_votes** - how many votes (one vote is one pc rotation & permutation) should be used to eval the model
#
# Returns:
#
#   ** same as *eval_one_epoch* **

# %%
def evaluate(model_num, num_votes, verbose=False):
    is_training = False
    
    # Reset
    tf.reset_default_graph()
     
    with tf.device('/GPU:'+str(GPU_INDEX)):
        pointclouds_pl, labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
        is_training_pl = tf.placeholder(tf.bool, shape=())

        # simple model
        pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl)
        loss = MODEL.get_loss(pred, labels_pl, end_points)

        # Add ops to save and restore all the variables.
        saver = tf.train.Saver()
        
    # Create a session
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.allow_soft_placement = True
    config.log_device_placement = True
    sess = tf.Session(config=config)

    # Get model path
    model_path = os.path.join(MODEL_DIR, 'model_' + str(model_num) + '.ckpt')
    
    # Restore variables from disk.
    saver.restore(sess, model_path)
    if verbose:
        print("Model restored.")

    ops = {'pointclouds_pl': pointclouds_pl,
           'labels_pl': labels_pl,
           'is_training_pl': is_training_pl,
           'pred': pred,
           'loss': loss}

    return eval_one_epoch(sess, ops, num_votes, verbose)

# %% [markdown]
# # # # # # # # # # # # # # # # # # # # # # # # # # # #
# # NUM_VOTES TEST
# # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
NUM_VOTES = 15
RANGE_MODELS = range(1,11)
num_votes_accs = {i: [] for i in RANGE_MODELS}
for i in num_votes_accs:
    for x in range(1, NUM_VOTES+1):
        _, acc, _, _, _ = evaluate(model_num=i, num_votes=x, verbose=False)
        num_votes_accs[i].append(acc)
        print ('i=', i, 'x=', x, 'acc = ', acc)
# Out:
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 1, 'acc = ', 0.9120745542949756)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 2, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 3, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 4, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 5, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 6, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 7, 'acc = ', 0.9136952998379254)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 8, 'acc = ', 0.9136952998379254)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 9, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 10, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 11, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 12, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 13, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 14, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('i=', 1, 'x=', 15, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 1, 'acc = ', 0.9092382495948136)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 2, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 3, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 4, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 5, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 6, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 7, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 8, 'acc = ', 0.9173419773095624)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 9, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 10, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 11, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 12, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 13, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 14, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('i=', 2, 'x=', 15, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 1, 'acc = ', 0.9080226904376013)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 2, 'acc = ', 0.9100486223662885)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 3, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 4, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 5, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 6, 'acc = ', 0.9108589951377634)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 7, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 8, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 9, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 10, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 11, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 12, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 13, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 14, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('i=', 3, 'x=', 15, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 1, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 2, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 3, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 4, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 5, 'acc = ', 0.9193679092382496)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 6, 'acc = ', 0.9185575364667747)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 7, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 8, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 9, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 10, 'acc = ', 0.9189627228525121)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 11, 'acc = ', 0.919773095623987)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 12, 'acc = ', 0.9173419773095624)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 13, 'acc = ', 0.9185575364667747)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 14, 'acc = ', 0.9181523500810372)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('i=', 4, 'x=', 15, 'acc = ', 0.9181523500810372)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 1, 'acc = ', 0.9076175040518638)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 2, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 3, 'acc = ', 0.9124797406807131)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 4, 'acc = ', 0.9128849270664505)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 5, 'acc = ', 0.9136952998379254)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 6, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 7, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 8, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 9, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 10, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 11, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 12, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 13, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 14, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('i=', 5, 'x=', 15, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 1, 'acc = ', 0.9112641815235009)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 2, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 3, 'acc = ', 0.9181523500810372)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 4, 'acc = ', 0.9189627228525121)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 5, 'acc = ', 0.9201782820097245)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 6, 'acc = ', 0.9209886547811994)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 7, 'acc = ', 0.9213938411669368)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 8, 'acc = ', 0.919773095623987)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 9, 'acc = ', 0.9185575364667747)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 10, 'acc = ', 0.9209886547811994)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 11, 'acc = ', 0.9205834683954619)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 12, 'acc = ', 0.9185575364667747)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 13, 'acc = ', 0.9213938411669368)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 14, 'acc = ', 0.9217990275526742)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('i=', 6, 'x=', 15, 'acc = ', 0.9193679092382496)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 1, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 2, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 3, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 4, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 5, 'acc = ', 0.9173419773095624)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 6, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 7, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 8, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 9, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 10, 'acc = ', 0.9181523500810372)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 11, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 12, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 13, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 14, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('i=', 7, 'x=', 15, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 1, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 2, 'acc = ', 0.9136952998379254)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 3, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 4, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 5, 'acc = ', 0.9173419773095624)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 6, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 7, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 8, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 9, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 10, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 11, 'acc = ', 0.9181523500810372)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 12, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 13, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 14, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('i=', 8, 'x=', 15, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 1, 'acc = ', 0.9096434359805511)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 2, 'acc = ', 0.9084278768233387)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 3, 'acc = ', 0.9136952998379254)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 4, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 5, 'acc = ', 0.9128849270664505)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 6, 'acc = ', 0.910453808752026)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 7, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 8, 'acc = ', 0.910453808752026)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 9, 'acc = ', 0.9100486223662885)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 10, 'acc = ', 0.9120745542949756)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 11, 'acc = ', 0.9108589951377634)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 12, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 13, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 14, 'acc = ', 0.9108589951377634)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('i=', 9, 'x=', 15, 'acc = ', 0.9120745542949756)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 1, 'acc = ', 0.910453808752026)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 2, 'acc = ', 0.9112641815235009)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 3, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 4, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 5, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 6, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 7, 'acc = ', 0.916936790923825)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 8, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 9, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 10, 'acc = ', 0.9193679092382496)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 11, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 12, 'acc = ', 0.9165316045380876)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 13, 'acc = ', 0.9157212317666127)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 14, 'acc = ', 0.9149108589951378)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('i=', 10, 'x=', 15, 'acc = ', 0.9189627228525121)

# %%
for i in num_votes_accs:
    plt.plot(np.arange(1, 1+len(num_votes_accs[i])), num_votes_accs[i])

# %%
num_votes_accs_np = np.zeros((max(RANGE_MODELS), NUM_VOTES), dtype=np.float)
for i in num_votes_accs:
    num_votes_accs_np[i-1] = num_votes_accs[i]
    np.save('log/num_votes_accs.npy', num_votes_accs_np)

# %% [markdown]
# # # # # # # # # # # # # # # # # # # # # # # # # #
# # MODEL ENSEMBLING
# # # # # # # # # # # # # # # # # # # # # # # # # #
#
# ## Calculate probabilities for each test cloud and each model. The output probability array will be the shape of (N, 40, X), where N is the test cloud len and X is the models count to be ensembled.

# %%
NUM_MODELS = 10
NUM_VOTES = 12
probabilities = []
true_labels = []
accuracies = []
for x in range(1, NUM_MODELS+1):
    _, acc, _, pred_vals, true_vals = evaluate(model_num=x, num_votes=NUM_VOTES, verbose=False)
    probabilities.append(pred_vals)
    accuracies.append(acc)
    true_labels = np.array(true_vals)
    print ('Model =', x, 'acc = ', acc)
    
probabilities = np.stack(probabilities).transpose(1, 2, 0)
accuracies = np.array(accuracies)
# Out:
# INFO:tensorflow:Restoring parameters from log/model_1.ckpt
# ('Model =', 1, 'acc = ', 0.9145056726094003)
# INFO:tensorflow:Restoring parameters from log/model_2.ckpt
# ('Model =', 2, 'acc = ', 0.9141004862236629)
# INFO:tensorflow:Restoring parameters from log/model_3.ckpt
# ('Model =', 3, 'acc = ', 0.913290113452188)
# INFO:tensorflow:Restoring parameters from log/model_4.ckpt
# ('Model =', 4, 'acc = ', 0.9173419773095624)
# INFO:tensorflow:Restoring parameters from log/model_5.ckpt
# ('Model =', 5, 'acc = ', 0.9161264181523501)
# INFO:tensorflow:Restoring parameters from log/model_6.ckpt
# ('Model =', 6, 'acc = ', 0.9185575364667747)
# INFO:tensorflow:Restoring parameters from log/model_7.ckpt
# ('Model =', 7, 'acc = ', 0.9177471636952999)
# INFO:tensorflow:Restoring parameters from log/model_8.ckpt
# ('Model =', 8, 'acc = ', 0.9153160453808752)
# INFO:tensorflow:Restoring parameters from log/model_9.ckpt
# ('Model =', 9, 'acc = ', 0.9116693679092382)
# INFO:tensorflow:Restoring parameters from log/model_10.ckpt
# ('Model =', 10, 'acc = ', 0.9165316045380876)

# %%
np.save('log/probabilities.npy', probabilities)
np.save('log/true_labels.npy', true_labels)
np.save('log/accuracies.npy', accuracies)

# %% [markdown]
# # Models evaluation statistics

# %%
print('Mean accuracy =', statistics.mean(accuracies))
indices = {}
for k in range(40):
    indices[k] = [i for i, x in enumerate(true_labels) if x == k]
    
validation_max_res = []
test_res_at_validation_max = []

for _ in range(1000):
    validation_indices = []
    test_indices = []
    for k in indices:
        random.shuffle(indices[k])
        split_idx = int(len(indices[k])/2)
        validation_indices += indices[k][:split_idx]
        test_indices += indices[k][split_idx:]
    validation_indices = sorted(validation_indices)
    test_indices = sorted(test_indices)

    validation_true_labels = true_labels[validation_indices]
    validation_probabilities = probabilities[validation_indices]
    test_true_labels = true_labels[test_indices]
    test_probabilities = probabilities[test_indices]

    validation_predictions = np.argmax(validation_probabilities, axis=1)
    validation_compare = np.equal(validation_predictions, np.expand_dims(validation_true_labels, -1))
    validation_accuracies = np.mean(validation_compare, axis=0)

    test_predictions = np.argmax(test_probabilities, axis=1)
    test_compare = np.equal(test_predictions, np.expand_dims(test_true_labels, -1))
    test_accuracies = np.mean(test_compare, axis=0)

    validation_max_res.append(np.max(validation_accuracies))
    test_res_at_validation_max.append(test_accuracies[np.argmax(validation_accuracies)])
    
mean_valid_max = statistics.mean(validation_max_res)
mean_test_at_valid_max = statistics.mean(test_res_at_validation_max)

print('Mean of validation max results =', mean_valid_max)
print('Mean of test result for validation max =', mean_test_at_valid_max)
# Out:
# ('Mean accuracy =', 0.9155186385737439)
# ('Mean of validation max results =', 0.9204448946515397)
# ('Mean of test result for validation max =', 0.9144959481361427)

# %% [markdown]
# # Agregate the outputs with sum operation

# %%
aggregated_probability = np.sum(probabilities, axis=-1)
aggregated_predictions = np.argmax(aggregated_probability, axis=-1)
float(np.sum(aggregated_predictions == true_labels)) / len(true_labels)
# Out:
# 0.9201782820097245

# %% [markdown]
# # Agregate the outputs with mean operation

# %%
aggregated_probability = np.mean(probabilities, axis=-1)
aggregated_predictions = np.argmax(aggregated_probability, axis=-1)
float(np.sum(aggregated_predictions == true_labels)) / len(true_labels)
# Out:
# 0.9201782820097245

# %% [markdown]
# # Agregate the outputs with mode operation

# %%
aggregated_predictions = np.argmax(probabilities, axis=1)
aggregated_predictions =  np.squeeze(stats.mode(aggregated_predictions, axis=1)[0])
float(np.sum(aggregated_predictions == true_labels)) / len(true_labels)
# Out:
# 0.9201782820097245
